# %% [markdown]
# ## UGV Navigation Recruitment Test

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
src.create(rows, cols, CV_8UC1);
img = cv2.imread(input_image.png, CV_8UC1);
#img = cv2.imread('input_image.png')
rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6cdd88896d33> in <module>
# ----> 1 src.create(rows, cols, CV_8UC1);
#       2 img = cv2.imread(input_image.png, CV_8UC1);
#       3 #img = cv2.imread('input_image.png')
#       4 rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       5 hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
#
# NameError: name 'src' is not defined

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(rgb)
plt.show()

# %%
th1 = cv2.adaptiveThreshold(rgb,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-b325fe7738bc> in <module>
# ----> 1 th1 = cv2.adaptiveThreshold(rgb,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
#
# error: OpenCV(4.1.0) C:\projects\opencv-python\opencv\modules\imgproc\src\thresh.cpp:1627: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'cv::adaptiveThreshold'

# %%
lower_white = np.array([90,20,100])
upper_white = np.array([180,170,255])

# %%
mask = cv2.inRange(hsv,lower_white,upper_white)
res1 = cv2.bitwise_and(rgb,rgb,mask=mask)

# %%
plt.imshow(res1)
plt.show()

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.erode(mask,kernel,iterations=1)

# %%
res2 = cv2.bitwise_and(rgb,rgb,mask=erosion)

# %%
plt.imshow(res2)
plt.show()
